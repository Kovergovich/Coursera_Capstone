# %% [markdown]
# # Recommendation for a new restaraunt location

# %% [markdown]
# ### 1. Introduction:
# ### 1.1 Background/Interest

# %% [markdown]
# #### We have a client who'd like to open a restaurant in Minsk, Belarus. We would need to analyze the city and its neighborhoods to find the best location to do so.

# %% [markdown]
# ### 1.2 Idea

# %% [markdown]
# #### This project aims to recommend the best possible location for a new restaraunt.
